# %%
import pandas as pd

# %%
Dataset=pd.read_csv("insurance_pre.csv")

# %%
Dataset=pd.get_dummies(Dataset,dtype=int,drop_first=True)

# %%
Dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
Independent=Dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
Dependent=Dataset[['charges']]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
Independent=sc.fit_transform(Independent)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
Param_grid={'criterion':['squared_error','absolute_error','friedman_mse','poisson'],
            'max_features': ['sqrt','log2',None],
            'splitter':['best','random']}

# %%
grid = GridSearchCV(DecisionTreeRegressor(), Param_grid, refit = True, verbose= 3,n_jobs=-1)
grid.fit(Independent,Dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
grid_Pred=grid.predict(Independent)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'poisson', 'max_features': None, 'splitter': 'best'}:

# %%
from sklearn.metrics import r2_score
r_score=r2_score(grid_Pred,Dependent)
print(r_score)
# Out:
# 0.9986653772918882

# %%
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'poisson', 'max_features': None, 'splitter': 'best'}:

# %%
table=pd.DataFrame.from_dict(re)
print(table)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.010906      0.003489         0.003233        0.000695
# 1        0.008414      0.004070         0.011100        0.014763
# 2        0.008536      0.001480         0.003614        0.001462
# 3        0.006899      0.002145         0.004175        0.001258
# 4        0.014365      0.009513         0.005475        0.001741
# 5        0.006536      0.000524         0.004320        0.001610
# 6        0.043224      0.004108         0.002511        0.000554
# 7        0.029157      0.006368         0.004360        0.001977
# 8        0.041691      0.011858         0.002955        0.000589
# 9        0.030554      0.006156         0.002672        0.000732
# 10       0.069292      0.015849         0.004971        0.003997
# 11       0.053607      0.009827         0.004529        0.000613
# 12       0.008237      0.003160         0.003844        0.002919
# 13       0.004849      0.000531         0.003838        0.000672
# 14       0.006230      0.000407         0.002450        0.000891
# 15       0.005587      0.001942         0.002454        0.000332
# 16       0.010917      0.001116         0.003575        0.001880
# 17       0.008226      0.003521         0.002448        0.000399
# 18       0.010084      0.002531         0.002335        0.000526
# 19       0.007890      0.002852         0.002547        0.000360
# 20       0.019411      0.015083         0.002474        0.000387
# 21       0.006108      0.000690         0.002779        0.000698
# 22       0.010844      0.000871         0.002205        0.000356
# 23       0.007221      0.000665         0.002439        0.000485
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4    squared_error               None           best
# 5    squared_error               None         random
# 6   absolute_error               sqrt           best
# 7   absolute_error               sqrt         random
# 8   absolute_error               log2           best
# 9   absolute_error               log2         random
# 10  absolute_error               None           best
# 11  absolute_error               None         random
# 12    friedman_mse               sqrt           best
# 13    friedman_mse               sqrt         random
# 14    friedman_mse               log2           best
# 15    friedman_mse               log2         random
# 16    friedman_mse               None           best
# 17    friedman_mse               None         random
# 18         poisson               sqrt           best
# 19         poisson               sqrt         random
# 20         poisson               log2           best
# 21         poisson               log2         random
# 22         poisson               None           best
# 23         poisson               None         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.694301
# 1   {'criterion': 'squared_error', 'max_features':...           0.718839
# 2   {'criterion': 'squared_error', 'max_features':...           0.607745
# 3   {'criterion': 'squared_error', 'max_features':...           0.626558
# 4   {'criterion': 'squared_error', 'max_features':...           0.742192
# 5   {'criterion': 'squared_error', 'max_features':...           0.706952
# 6   {'criterion': 'absolute_error', 'max_features'...           0.582088
# 7   {'criterion': 'absolute_error', 'max_features'...           0.610422
# 8   {'criterion': 'absolute_error', 'max_features'...           0.696644
# 9   {'criterion': 'absolute_error', 'max_features'...           0.725480
# 10  {'criterion': 'absolute_error', 'max_features'...           0.736874
# 11  {'criterion': 'absolute_error', 'max_features'...           0.710508
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.731181
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.679726
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.661662
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.634177
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.733608
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.697918
# 18  {'criterion': 'poisson', 'max_features': 'sqrt...           0.695158
# 19  {'criterion': 'poisson', 'max_features': 'sqrt...           0.614293
# 20  {'criterion': 'poisson', 'max_features': 'log2...           0.744758
# 21  {'criterion': 'poisson', 'max_features': 'log2...           0.658634
# 22  {'criterion': 'poisson', 'max_features': None,...           0.744670
# 23  {'criterion': 'poisson', 'max_features': None,...           0.720408
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.499434           0.687216           0.728272
# 1            0.566464           0.660217           0.620249
# 2            0.639319           0.743028           0.649236
# 3            0.579920           0.683625           0.704007
# 4            0.658715           0.733584           0.736200
# 5            0.613031           0.687051           0.700726
# 6            0.537611           0.658264           0.684237
# 7            0.591779           0.526919           0.700313
# 8            0.535997           0.385496           0.711636
# 9            0.669963           0.711542           0.726376
# 10           0.615948           0.740154           0.715030
# 11           0.542898           0.724290           0.749183
# 12           0.504761           0.601509           0.665013
# 13           0.515634           0.644140           0.671585
# 14           0.564421           0.465966           0.643500
# 15           0.610853           0.688878           0.571509
# 16           0.632784           0.732536           0.743892
# 17           0.582275           0.665041           0.709908
# 18           0.644495           0.576038           0.722478
# 19           0.604575           0.682468           0.728308
# 20           0.621889           0.794743           0.605227
# 21           0.551691           0.693186           0.715554
# 22           0.663135           0.739362           0.723841
# 23           0.565870           0.695424           0.777895
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.635061         0.648857        0.080450               17
# 1            0.720541         0.657262        0.059024               15
# 2            0.691193         0.666104        0.046807               13
# 3            0.655972         0.650016        0.043689               16
# 4            0.689067         0.711951        0.032644                3
# 5            0.711341         0.683820        0.036331                9
# 6            0.770110         0.646462        0.081053               18
# 7            0.623992         0.610685        0.055829               22
# 8            0.712726         0.608500        0.129813               24
# 9            0.588760         0.684424        0.052041                8
# 10           0.760041         0.713609        0.050876                2
# 11           0.758229         0.697022        0.078926                5
# 12           0.729737         0.646440        0.085506               19
# 13           0.708154         0.643848        0.067277               20
# 14           0.707123         0.608534        0.084896               23
# 15           0.646103         0.630304        0.038809               21
# 16           0.690876         0.706739        0.041204                4
# 17           0.675359         0.666100        0.044822               14
# 18           0.705023         0.668638        0.053073               11
# 19           0.706047         0.667138        0.049391               12
# 20           0.716939         0.696711        0.072520                6
# 21           0.734277         0.670668        0.064604               10
# 22           0.722084         0.718618        0.029075                1
# 23           0.703200         0.692560        0.069612                7

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[63770.42801]

# %%
import pickle
Filename="Finalize_DecisionTree_Model.sav"
pickle.dump(grid,open(Filename,"wb"))

# %%
loaded_model=pickle.load(open("Finalize_DecisionTree_Model.sav","rb"))
pre_input=sc.transform([[20,29,0,0,1]])
result=loaded_model.predict(pre_input)
print(result)
# Out:
# [17748.5062]
# c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
