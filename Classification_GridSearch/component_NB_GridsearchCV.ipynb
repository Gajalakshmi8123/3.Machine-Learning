# %%
import pandas as pd

# %%
Dataset=pd.read_csv('social_network_ads_classification.csv')

# %%
Dataset.head()
# Out:
#    UserID  Gender  Age  EstimatedSalary  Purchased
# 0       1    Male   56            20237          1
# 1       2  Female   46            35056          0
# 2       3  Female   32           129548          1
# 3       4  Female   25           126488          0
# 4       5  Female   38           149415          0

# %%
Dataset=pd.get_dummies(Dataset,dtype=int,drop_first=True)

# %%
Dataset.columns
# Out:
# Index(['UserID', 'Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
Independent=Dataset[['Age', 'EstimatedSalary', 'Gender_Male']]
Dependent=Dataset[['Purchased']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(Independent,Dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
scx=StandardScaler()
X_train=scx.fit_transform(X_train)
X_test=scx.transform(X_test)

# %%
from sklearn.naive_bayes import ComplementNB
from sklearn.model_selection import GridSearchCV

param_grid = {
    'alpha': [0.1, 0.5, 1.0, 2.0, 5.0, 10.0],
    'fit_prior': [True, False],
    'norm': [True, False]
}

grid=GridSearchCV(ComplementNB(), param_grid, refit=True, n_jobs=-1)
grid.fit(X_train, Y_train)
# Out:
# c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=ComplementNB(), n_jobs=-1,
#              param_grid={'alpha': [0.1, 0.5, 1.0, 2.0, 5.0, 10.0],
#                          'fit_prior': [True, False], 'norm': [True, False]})

# %%
re=grid.cv_results_

# %%
grid_Pred=grid.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(grid_Pred,Y_test)
print(cm)
# Out:
# [[30 30]
#  [31 29]]

# %%
from sklearn.metrics import classification_report
clf_report=classification_report(grid_Pred,Y_test)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.50      0.50        60
#            1       0.49      0.48      0.49        60
#
#     accuracy                           0.49       120
#    macro avg       0.49      0.49      0.49       120
# weighted avg       0.49      0.49      0.49       120

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(grid_Pred,Y_test)
print("The f1 sore of the best parameter{}:".format(grid.best_params_),f1_score)
# Out:
# The f1 sore of the best parameter{'alpha': 5.0, 'fit_prior': True, 'norm': False}: <function f1_score at 0x00000173CF6A6C00>

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(Y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 0.4812447902195054

# %%
table=pd.DataFrame.from_dict(re)
print(table)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0        0.014994      0.004427         0.005374        0.002846         0.1
# 1        0.009970      0.005815         0.010080        0.008034         0.1
# 2        0.003414      0.002925         0.004150        0.002219         0.1
# 3        0.005670      0.004610         0.001407        0.002815         0.1
# 4        0.005509      0.002405         0.002288        0.002175         0.5
# 5        0.009154      0.002703         0.000000        0.000000         0.5
# 6        0.002337      0.001198         0.007694        0.002515         0.5
# 7        0.003706      0.002875         0.007366        0.003167         0.5
# 8        0.004518      0.003652         0.004974        0.004009         1.0
# 9        0.007904      0.003969         0.002220        0.003948         1.0
# 10       0.006930      0.004005         0.002052        0.004104         1.0
# 11       0.005838      0.004128         0.006843        0.003264         1.0
# 12       0.005040      0.003370         0.004633        0.003854         2.0
# 13       0.003715      0.004619         0.006835        0.004619         2.0
# 14       0.005905      0.003128         0.005626        0.003351         2.0
# 15       0.006984      0.003237         0.003265        0.002779         2.0
# 16       0.002517      0.001489         0.010326        0.005109         5.0
# 17       0.005610      0.001918         0.003469        0.002198         5.0
# 18       0.005112      0.002168         0.004118        0.001527         5.0
# 19       0.006852      0.002767         0.003319        0.003355         5.0
# 20       0.005734      0.004713         0.006158        0.005156        10.0
# 21       0.005669      0.003930         0.006618        0.003170        10.0
# 22       0.007381      0.002682         0.004873        0.000737        10.0
# 23       0.004840      0.001412         0.001508        0.003015        10.0
#
#    param_fit_prior param_norm  \
# 0             True       True
# 1             True      False
# 2            False       True
# 3            False      False
# 4             True       True
# 5             True      False
# 6            False       True
# 7            False      False
# 8             True       True
# 9             True      False
# 10           False       True
# 11           False      False
# 12            True       True
# 13            True      False
# 14           False       True
# 15           False      False
# 16            True       True
# 17            True      False
# 18           False       True
# 19           False      False
# 20            True       True
# 21            True      False
# 22           False       True
# 23           False      False
#
#                                                params  split0_test_score  \
# 0     {'alpha': 0.1, 'fit_prior': True, 'norm': True}           0.607143
# 1    {'alpha': 0.1, 'fit_prior': True, 'norm': False}           0.500000
# 2    {'alpha': 0.1, 'fit_prior': False, 'norm': True}           0.607143
# 3   {'alpha': 0.1, 'fit_prior': False, 'norm': False}           0.500000
# 4     {'alpha': 0.5, 'fit_prior': True, 'norm': True}           0.589286
# 5    {'alpha': 0.5, 'fit_prior': True, 'norm': False}           0.500000
# 6    {'alpha': 0.5, 'fit_prior': False, 'norm': True}           0.589286
# 7   {'alpha': 0.5, 'fit_prior': False, 'norm': False}           0.500000
# 8     {'alpha': 1.0, 'fit_prior': True, 'norm': True}           0.589286
# 9    {'alpha': 1.0, 'fit_prior': True, 'norm': False}           0.500000
# 10   {'alpha': 1.0, 'fit_prior': False, 'norm': True}           0.589286
# 11  {'alpha': 1.0, 'fit_prior': False, 'norm': False}           0.500000
# 12    {'alpha': 2.0, 'fit_prior': True, 'norm': True}           0.589286
# 13   {'alpha': 2.0, 'fit_prior': True, 'norm': False}           0.500000
# 14   {'alpha': 2.0, 'fit_prior': False, 'norm': True}           0.589286
# 15  {'alpha': 2.0, 'fit_prior': False, 'norm': False}           0.500000
# 16    {'alpha': 5.0, 'fit_prior': True, 'norm': True}           0.589286
# 17   {'alpha': 5.0, 'fit_prior': True, 'norm': False}           0.500000
# 18   {'alpha': 5.0, 'fit_prior': False, 'norm': True}           0.589286
# 19  {'alpha': 5.0, 'fit_prior': False, 'norm': False}           0.500000
# 20   {'alpha': 10.0, 'fit_prior': True, 'norm': True}           0.589286
# 21  {'alpha': 10.0, 'fit_prior': True, 'norm': False}           0.500000
# 22  {'alpha': 10.0, 'fit_prior': False, 'norm': True}           0.589286
# 23  {'alpha': 10.0, 'fit_prior': False, 'norm': Fa...           0.500000
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.464286           0.464286           0.535714
# 1            0.589286           0.500000           0.642857
# 2            0.464286           0.464286           0.535714
# 3            0.589286           0.500000           0.642857
# 4            0.464286           0.464286           0.535714
# 5            0.589286           0.500000           0.642857
# 6            0.464286           0.464286           0.535714
# 7            0.589286           0.500000           0.642857
# 8            0.464286           0.464286           0.535714
# 9            0.589286           0.500000           0.642857
# 10           0.464286           0.464286           0.535714
# 11           0.589286           0.500000           0.642857
# 12           0.446429           0.464286           0.535714
# 13           0.589286           0.500000           0.642857
# 14           0.446429           0.464286           0.535714
# 15           0.589286           0.500000           0.642857
# 16           0.428571           0.464286           0.535714
# 17           0.607143           0.500000           0.660714
# 18           0.428571           0.464286           0.535714
# 19           0.607143           0.500000           0.660714
# 20           0.464286           0.464286           0.535714
# 21           0.607143           0.500000           0.642857
# 22           0.464286           0.464286           0.535714
# 23           0.607143           0.500000           0.642857
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.482143         0.510714        0.054865               13
# 1            0.446429         0.535714        0.070530                5
# 2            0.482143         0.510714        0.054865               13
# 3            0.446429         0.535714        0.070530                5
# 4            0.482143         0.507143        0.048708               15
# 5            0.446429         0.535714        0.070530                5
# 6            0.482143         0.507143        0.048708               15
# 7            0.446429         0.535714        0.070530                5
# 8            0.482143         0.507143        0.048708               15
# 9            0.446429         0.535714        0.070530                5
# 10           0.482143         0.507143        0.048708               15
# 11           0.446429         0.535714        0.070530                5
# 12           0.482143         0.503571        0.052245               21
# 13           0.446429         0.535714        0.070530                5
# 14           0.482143         0.503571        0.052245               21
# 15           0.446429         0.535714        0.070530                5
# 16           0.482143         0.500000        0.056469               23
# 17           0.446429         0.542857        0.078734                1
# 18           0.482143         0.500000        0.056469               23
# 19           0.446429         0.542857        0.078734                1
# 20           0.482143         0.507143        0.048708               15
# 21           0.446429         0.539286        0.073540                3
# 22           0.482143         0.507143        0.048708               15
# 23           0.446429         0.539286        0.073540                3

# %%
age_input=int(input("Enter the age: "))
Estimated_Salary=int(input("Enter the salary: "))
sex_male_input=int(input('sex male 0 or 1: '))

# %%
Future_predict=grid.predict([[age_input, Estimated_Salary,sex_male_input]])
print(Future_predict)
