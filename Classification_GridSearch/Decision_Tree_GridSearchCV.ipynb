# %%
import pandas as pd

# %%
Dataset=pd.read_csv('social_network_ads_classification.csv')

# %%
Dataset.head()
# Out:
#    UserID  Gender  Age  EstimatedSalary  Purchased
# 0       1    Male   56            20237          1
# 1       2  Female   46            35056          0
# 2       3  Female   32           129548          1
# 3       4  Female   25           126488          0
# 4       5  Female   38           149415          0

# %%
Dataset=pd.get_dummies(Dataset,dtype=int,drop_first=True)

# %%
Dataset.columns
# Out:
# Index(['UserID', 'Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
Independent=Dataset[['Age', 'EstimatedSalary', 'Gender_Male']]
Dependent=Dataset[['Purchased']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(Independent,Dependent,test_size=0.30,random_state=0)

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.tree import DecisionTreeClassifier

Param_grid={'criterion':['gini', 'entropy', 'log_loss'],
            'max_features': ['sqrt','log2',None],
            'splitter':['best','random']
           }
grid = GridSearchCV(DecisionTreeClassifier(), Param_grid, refit = True, verbose = 3,n_jobs=-1,scoring='f1_weighted') 

grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'splitter': ['best', 'random']},
#              scoring='f1_weighted', verbose=3)

# %%
re=grid.cv_results_

# %%
grid_Pred=grid.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(grid_Pred,Y_test)
print(cm)
# Out:
# [[36 37]
#  [25 22]]

# %%
from sklearn.metrics import classification_report
clf_report=classification_report(grid_Pred,Y_test)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.49      0.54        73
#            1       0.37      0.47      0.42        47
#
#     accuracy                           0.48       120
#    macro avg       0.48      0.48      0.48       120
# weighted avg       0.51      0.48      0.49       120

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(grid_Pred,Y_test)
print("The f1 sore of the best parameter{}:".format(grid.best_params_),f1_score)
# Out:
# The f1 sore of the best parameter{'criterion': 'log_loss', 'max_features': None, 'splitter': 'random'}: <function f1_score at 0x0000015C660C40E0>

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(Y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 0.4815226451792164

# %%
table=pd.DataFrame.from_dict(re)
print(table)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.011246      0.002142         0.009992        0.000855
# 1        0.009503      0.002685         0.013074        0.003898
# 2        0.006975      0.002875         0.007265        0.003950
# 3        0.004027      0.004932         0.013457        0.004101
# 4        0.005883      0.005801         0.014063        0.004869
# 5        0.007245      0.000988         0.009607        0.001023
# 6        0.007251      0.003550         0.008266        0.003372
# 7        0.006046      0.004098         0.011330        0.002843
# 8        0.005729      0.004013         0.016639        0.007599
# 9        0.005609      0.003752         0.010309        0.001191
# 10       0.010037      0.004211         0.009797        0.001545
# 11       0.004885      0.003444         0.010043        0.000188
# 12       0.003966      0.002280         0.010087        0.000033
# 13       0.003031      0.003706         0.011853        0.003209
# 14       0.002912      0.002738         0.011778        0.005941
# 15       0.004591      0.004656         0.009878        0.000401
# 16       0.004446      0.003872         0.011826        0.002885
# 17       0.005962      0.004650         0.006513        0.004904
#
#    param_criterion param_max_features param_splitter  \
# 0             gini               sqrt           best
# 1             gini               sqrt         random
# 2             gini               log2           best
# 3             gini               log2         random
# 4             gini               None           best
# 5             gini               None         random
# 6          entropy               sqrt           best
# 7          entropy               sqrt         random
# 8          entropy               log2           best
# 9          entropy               log2         random
# 10         entropy               None           best
# 11         entropy               None         random
# 12        log_loss               sqrt           best
# 13        log_loss               sqrt         random
# 14        log_loss               log2           best
# 15        log_loss               log2         random
# 16        log_loss               None           best
# 17        log_loss               None         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.391300
# 1   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.419643
# 2   {'criterion': 'gini', 'max_features': 'log2', ...           0.316175
# 3   {'criterion': 'gini', 'max_features': 'log2', ...           0.407888
# 4   {'criterion': 'gini', 'max_features': None, 's...           0.355495
# 5   {'criterion': 'gini', 'max_features': None, 's...           0.428252
# 6   {'criterion': 'entropy', 'max_features': 'sqrt...           0.427106
# 7   {'criterion': 'entropy', 'max_features': 'sqrt...           0.532120
# 8   {'criterion': 'entropy', 'max_features': 'log2...           0.496129
# 9   {'criterion': 'entropy', 'max_features': 'log2...           0.551419
# 10  {'criterion': 'entropy', 'max_features': None,...           0.355495
# 11  {'criterion': 'entropy', 'max_features': None,...           0.535714
# 12  {'criterion': 'log_loss', 'max_features': 'sqr...           0.391306
# 13  {'criterion': 'log_loss', 'max_features': 'sqr...           0.515544
# 14  {'criterion': 'log_loss', 'max_features': 'log...           0.570330
# 15  {'criterion': 'log_loss', 'max_features': 'log...           0.388187
# 16  {'criterion': 'log_loss', 'max_features': None...           0.374400
# 17  {'criterion': 'log_loss', 'max_features': None...           0.498718
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.458705           0.533917           0.490323
# 1            0.464286           0.464970           0.518319
# 2            0.458705           0.536307           0.422711
# 3            0.426359           0.458705           0.462212
# 4            0.478620           0.422619           0.482638
# 5            0.474652           0.500639           0.464286
# 6            0.411280           0.482638           0.392857
# 7            0.482640           0.446958           0.428571
# 8            0.429301           0.478665           0.464970
# 9            0.482638           0.514577           0.381106
# 10           0.478620           0.393633           0.498084
# 11           0.468917           0.550534           0.535714
# 12           0.458705           0.411280           0.392857
# 13           0.392857           0.428571           0.482640
# 14           0.498065           0.518319           0.445546
# 15           0.536307           0.474515           0.571976
# 16           0.474515           0.411280           0.517088
# 17           0.607143           0.464286           0.553999
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.510755         0.477000        0.049468               10
# 1            0.599379         0.493319        0.061560                5
# 2            0.658406         0.478461        0.114509                9
# 3            0.552854         0.461604        0.049926               13
# 4            0.464970         0.440868        0.047692               16
# 5            0.551020         0.483770        0.040871                8
# 6            0.586492         0.460075        0.069966               14
# 7            0.552854         0.488629        0.047740                7
# 8            0.482638         0.470341        0.022798               11
# 9            0.530878         0.492124        0.059895                6
# 10           0.464970         0.438160        0.054338               17
# 11           0.550534         0.528283        0.030414                2
# 12           0.500000         0.430830        0.042303               18
# 13           0.494792         0.462881        0.045305               12
# 14           0.526539         0.511759        0.040654                3
# 15           0.517082         0.497613        0.063109                4
# 16           0.446958         0.444848        0.049382               15
# 17           0.605622         0.545953        0.057044                1

# %%
age_input=int(input("Enter the age: "))
Estimated_Salary=int(input("Enter the salary: "))
sex_male_input=int(input('sex male 0 or 1: '))

# %%
Future_predict=grid.predict([[age_input, Estimated_Salary,sex_male_input]])
print(Future_predict)
# Out:
# [0]
# c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
