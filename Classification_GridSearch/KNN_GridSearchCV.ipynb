# %%
import pandas as pd

# %%
Dataset=pd.read_csv('social_network_ads_classification.csv')

# %%
Dataset.head()
# Out:
#    UserID  Gender  Age  EstimatedSalary  Purchased
# 0       1    Male   56            20237          1
# 1       2  Female   46            35056          0
# 2       3  Female   32           129548          1
# 3       4  Female   25           126488          0
# 4       5  Female   38           149415          0

# %%
Dataset=pd.get_dummies(Dataset,dtype=int,drop_first=True)

# %%
Dataset.columns
# Out:
# Index(['UserID', 'Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
Independent=Dataset[['Age', 'EstimatedSalary', 'Gender_Male']]
Dependent=Dataset[['Purchased']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(Independent,Dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
scx=StandardScaler()
X_train=scx.fit_transform(X_train)
X_test=scx.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_neighbors': [1, 3, 5, 7, 9, 11, 13, 15],
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
    'leaf_size': [10, 20, 30, 40, 50],
    'p': [1, 2]
}


grid=GridSearchCV(KNeighborsClassifier(), param_grid, refit=True, n_jobs=-1)
grid.fit(X_train,Y_train)
# Out:
# c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neighbors\_classification.py:238: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# GridSearchCV(estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'leaf_size': [10, 20, 30, 40, 50],
#                          'n_neighbors': [1, 3, 5, 7, 9, 11, 13, 15],
#                          'p': [1, 2], 'weights': ['uniform', 'distance']})

# %%
re=grid.cv_results_

# %%
grid_Pred=grid.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(grid_Pred,Y_test)
print(cm)
# Out:
# [[29 38]
#  [32 21]]

# %%
from sklearn.metrics import classification_report
clf_report=classification_report(grid_Pred,Y_test)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.43      0.45        67
#            1       0.36      0.40      0.38        53
#
#     accuracy                           0.42       120
#    macro avg       0.42      0.41      0.41       120
# weighted avg       0.42      0.42      0.42       120

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(grid_Pred,Y_test)
print("The f1 sore of the best parameter{}:".format(grid.best_params_),f1_score)
# Out:
# The f1 sore of the best parameter{'algorithm': 'auto', 'leaf_size': 10, 'n_neighbors': 1, 'p': 1, 'weights': 'uniform'}: <function f1_score at 0x0000027CFE41CB80>

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(Y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 0.4156710197277021

# %%
table=pd.DataFrame.from_dict(re)
print(table)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.023249      0.016544         0.012106        0.001055
# 1         0.013792      0.018416         0.005596        0.003759
# 2         0.004963      0.002577         0.009682        0.002515
# 3         0.004157      0.000411         0.005743        0.000691
# 4         0.002621      0.001512         0.012082        0.002497
# ..             ...           ...              ...             ...
# 635       0.009732      0.012032         0.003629        0.002304
# 636       0.017800      0.017958         0.012569        0.017413
# 637       0.005546      0.003550         0.002974        0.001061
# 638       0.001110      0.001213         0.004054        0.002799
# 639       0.002323      0.004062         0.007954        0.003114
#
#     param_algorithm param_leaf_size param_n_neighbors param_p param_weights  \
# 0              auto              10                 1       1       uniform
# 1              auto              10                 1       1      distance
# 2              auto              10                 1       2       uniform
# 3              auto              10                 1       2      distance
# 4              auto              10                 3       1       uniform
# ..              ...             ...               ...     ...           ...
# 635           brute              50                13       2      distance
# 636           brute              50                15       1       uniform
# 637           brute              50                15       1      distance
# 638           brute              50                15       2       uniform
# 639           brute              50                15       2      distance
#
#                                                 params  split0_test_score  \
# 0    {'algorithm': 'auto', 'leaf_size': 10, 'n_neig...           0.535714
# 1    {'algorithm': 'auto', 'leaf_size': 10, 'n_neig...           0.535714
# 2    {'algorithm': 'auto', 'leaf_size': 10, 'n_neig...           0.535714
# 3    {'algorithm': 'auto', 'leaf_size': 10, 'n_neig...           0.535714
# 4    {'algorithm': 'auto', 'leaf_size': 10, 'n_neig...           0.375000
# ..                                                 ...                ...
# 635  {'algorithm': 'brute', 'leaf_size': 50, 'n_nei...           0.428571
# 636  {'algorithm': 'brute', 'leaf_size': 50, 'n_nei...           0.428571
# 637  {'algorithm': 'brute', 'leaf_size': 50, 'n_nei...           0.410714
# 638  {'algorithm': 'brute', 'leaf_size': 50, 'n_nei...           0.428571
# 639  {'algorithm': 'brute', 'leaf_size': 50, 'n_nei...           0.392857
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 0             0.500000           0.571429           0.464286
# 1             0.500000           0.571429           0.464286
# 2             0.482143           0.571429           0.464286
# 3             0.482143           0.571429           0.464286
# 4             0.446429           0.571429           0.464286
# ..                 ...                ...                ...
# 635           0.517857           0.517857           0.500000
# 636           0.446429           0.500000           0.589286
# 637           0.464286           0.482143           0.535714
# 638           0.446429           0.500000           0.607143
# 639           0.500000           0.500000           0.571429
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0             0.571429         0.528571        0.041650                1
# 1             0.571429         0.528571        0.041650                1
# 2             0.535714         0.517857        0.039123               41
# 3             0.535714         0.517857        0.039123               41
# 4             0.482143         0.467857        0.063286              501
# ..                 ...              ...             ...              ...
# 635           0.517857         0.496429        0.034626              161
# 636           0.500000         0.492857        0.056016              221
# 637           0.500000         0.478571        0.041342              361
# 638           0.553571         0.507143        0.066432               81
# 639           0.517857         0.496429        0.058029              161
#
# [640 rows x 18 columns]

# %%
age_input=int(input("Enter the age: "))
Estimated_Salary=int(input("Enter the salary: "))
sex_male_input=int(input('sex male 0 or 1: '))

# %%
Future_predict=grid.predict([[age_input, Estimated_Salary,sex_male_input]])
print(Future_predict)
# Out:
# [0]
