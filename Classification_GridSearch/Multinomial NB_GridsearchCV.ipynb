# %%
import pandas as pd

# %%
Dataset=pd.read_csv('social_network_ads_classification.csv')

# %%
Dataset.head()
# Out:
#    UserID  Gender  Age  EstimatedSalary  Purchased
# 0       1    Male   56            20237          1
# 1       2  Female   46            35056          0
# 2       3  Female   32           129548          1
# 3       4  Female   25           126488          0
# 4       5  Female   38           149415          0

# %%
Dataset=pd.get_dummies(Dataset,dtype=int,drop_first=True)

# %%
Dataset.columns
# Out:
# Index(['UserID', 'Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
Independent=Dataset[['Age', 'EstimatedSalary', 'Gender_Male']]
Dependent=Dataset[['Purchased']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(Independent,Dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
scx=StandardScaler()
X_train=scx.fit_transform(X_train)
X_test=scx.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.naive_bayes import MultinomialNB

param_grid = {
    'alpha': [0.1, 0.5, 1.0, 2.0, 5.0, 10.0],
    'fit_prior': [True, False]
}

grid=GridSearchCV(MultinomialNB(), param_grid, refit=True, n_jobs=-1)
grid.fit(X_train,Y_train)
# Out:
# c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=MultinomialNB(), n_jobs=-1,
#              param_grid={'alpha': [0.1, 0.5, 1.0, 2.0, 5.0, 10.0],
#                          'fit_prior': [True, False]})

# %%
re=grid.cv_results_

# %%
grid_Pred=grid.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(grid_Pred,Y_test)
print(cm)
# Out:
# [[30 30]
#  [31 29]]

# %%
from sklearn.metrics import classification_report
clf_report=classification_report(grid_Pred,Y_test)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.50      0.50        60
#            1       0.49      0.48      0.49        60
#
#     accuracy                           0.49       120
#    macro avg       0.49      0.49      0.49       120
# weighted avg       0.49      0.49      0.49       120

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(grid_Pred,Y_test)
print("The f1 sore of the best parameter{}:".format(grid.best_params_),f1_score)
# Out:
# The f1 sore of the best parameter{'alpha': 5.0, 'fit_prior': False}: <function f1_score at 0x000002BEA47D89A0>

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(Y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 0.4812447902195054

# %%
table=pd.DataFrame.from_dict(re)
print(table)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0        0.018684      0.006962         0.007036    1.113897e-03         0.1
# 1        0.009848      0.002926         0.005951    7.656810e-04         0.1
# 2        0.006169      0.001483         0.006379    1.196603e-03         0.5
# 3        0.005182      0.001465         0.004187    3.981861e-04         0.5
# 4        0.004783      0.001324         0.005183    3.990417e-04         1.0
# 5        0.005383      0.000797         0.004983    4.101908e-07         1.0
# 6        0.004784      0.000398         0.005442    1.213823e-03         2.0
# 7        0.006899      0.001992         0.005100    1.486148e-03         2.0
# 8        0.004488      0.000893         0.006179    1.932907e-03         5.0
# 9        0.006181      0.001597         0.006178    1.466882e-03         5.0
# 10       0.006577      0.002409         0.006180    9.763392e-04        10.0
# 11       0.006778      0.001464         0.004586    4.903329e-04        10.0
#
#    param_fit_prior                               params  split0_test_score  \
# 0             True    {'alpha': 0.1, 'fit_prior': True}           0.517857
# 1            False   {'alpha': 0.1, 'fit_prior': False}           0.500000
# 2             True    {'alpha': 0.5, 'fit_prior': True}           0.517857
# 3            False   {'alpha': 0.5, 'fit_prior': False}           0.500000
# 4             True    {'alpha': 1.0, 'fit_prior': True}           0.535714
# 5            False   {'alpha': 1.0, 'fit_prior': False}           0.500000
# 6             True    {'alpha': 2.0, 'fit_prior': True}           0.535714
# 7            False   {'alpha': 2.0, 'fit_prior': False}           0.500000
# 8             True    {'alpha': 5.0, 'fit_prior': True}           0.535714
# 9            False   {'alpha': 5.0, 'fit_prior': False}           0.500000
# 10            True   {'alpha': 10.0, 'fit_prior': True}           0.535714
# 11           False  {'alpha': 10.0, 'fit_prior': False}           0.500000
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.517857           0.517857           0.500000
# 1            0.589286           0.500000           0.642857
# 2            0.517857           0.517857           0.500000
# 3            0.589286           0.500000           0.642857
# 4            0.517857           0.517857           0.517857
# 5            0.589286           0.500000           0.642857
# 6            0.517857           0.517857           0.517857
# 7            0.589286           0.500000           0.642857
# 8            0.517857           0.517857           0.517857
# 9            0.607143           0.500000           0.660714
# 10           0.517857           0.517857           0.517857
# 11           0.607143           0.500000           0.642857
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.482143         0.507143        0.014286               11
# 1            0.446429         0.535714        0.070530                3
# 2            0.482143         0.507143        0.014286               11
# 3            0.446429         0.535714        0.070530                3
# 4            0.482143         0.514286        0.017496                7
# 5            0.446429         0.535714        0.070530                3
# 6            0.482143         0.514286        0.017496                7
# 7            0.446429         0.535714        0.070530                3
# 8            0.482143         0.514286        0.017496                7
# 9            0.446429         0.542857        0.078734                1
# 10           0.482143         0.514286        0.017496                7
# 11           0.446429         0.539286        0.073540                2

# %%
age_input=int(input("Enter the age: "))
Estimated_Salary=int(input("Enter the salary: "))
sex_male_input=int(input('sex male 0 or 1: '))

# %%
Future_predict=grid.predict([[age_input, Estimated_Salary,sex_male_input]])
print(Future_predict)
