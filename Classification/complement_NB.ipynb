# %%
import pandas as pd

# %%
Dataset=pd.read_csv('social_network_ads_classification.csv')

# %%
Dataset.head()
# Out:
#    UserID  Gender  Age  EstimatedSalary  Purchased
# 0       1    Male   56            20237          1
# 1       2  Female   46            35056          0
# 2       3  Female   32           129548          1
# 3       4  Female   25           126488          0
# 4       5  Female   38           149415          0

# %%
Dataset=pd.get_dummies(Dataset,dtype=int,drop_first=True)

# %%
Dataset.columns
# Out:
# Index(['UserID', 'Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
Independent=Dataset[['Age', 'EstimatedSalary', 'Purchased', 'Gender_Male']]
Dependent=Dataset[['Purchased']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(Independent,Dependent,test_size=0.30,random_state=0)

# %%
from sklearn.naive_bayes import ComplementNB
classifier=ComplementNB()
classifier.fit(X_train,Y_train)
# Out:
# c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ComplementNB()

# %%
Y_Pred=classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_Pred,Y_test)
print(cm)
# Out:
# [[58  0]
#  [ 3 59]]

# %%
from sklearn.metrics import classification_report
clf_report=classification_report(Y_Pred,Y_test)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97        58
#            1       1.00      0.95      0.98        62
#
#     accuracy                           0.97       120
#    macro avg       0.98      0.98      0.97       120
# weighted avg       0.98      0.97      0.98       120

# %%
age_input=int(input("Enter the age: "))
salary_input=float(input("Enter the salary: "))
sex_male_input=int(input("Enter the sex 1 or 0: "))

# %%
classifier.predict([[age_input,salary_input,sex_male_input]])
# Out:
# c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but ComplementNB was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 classifier.predict([[age_input,salary_input,sex_male_input]])
#
# File c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\naive_bayes.py:101, in _BaseNB.predict(self, X)
#      87 """
#      88 Perform classification on an array of test vectors X.
#      89
#    (...)
#      98     Predicted target values for X.
#      99 """
#     100 check_is_fitted(self)
# --> 101 X = self._check_X(X)
#     102 jll = self._joint_log_likelihood(X)
#     103 return self.classes_[np.argmax(jll, axis=1)]
#
# File c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\naive_bayes.py:574, in _BaseDiscreteNB._check_X(self, X)
#     572 def _check_X(self, X):
#     573     """Validate X, used only in predict* methods."""
# --> 574     return self._validate_data(X, accept_sparse="csr", reset=False)
#
# File c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:654, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
# --> 654     self._check_n_features(X, reset=reset)
#     656 return out
#
# File c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:443, in BaseEstimator._check_n_features(self, X, reset)
#     440     return
#     442 if n_features != self.n_features_in_:
# --> 443     raise ValueError(
#     444         f"X has {n_features} features, but {self.__class__.__name__} "
#     445         f"is expecting {self.n_features_in_} features as input."
#     446     )
#
# ValueError: X has 3 features, but ComplementNB is expecting 4 features as input.
