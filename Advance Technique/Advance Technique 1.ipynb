# %%
import pandas as pd

# %%
Dataset=pd.read_csv('insurance_pre.csv')

# %%
print(Dataset.head())
# Out:
#    age     sex     bmi  children smoker      charges
# 0   19  female  27.900         0    yes  16884.92400
# 1   18    male  33.770         1     no   1725.55230
# 2   28    male  33.000         3     no   4449.46200
# 3   33    male  22.705         0     no  21984.47061
# 4   32    male  28.880         0     no   3866.85520

# %%
Dataset=pd.get_dummies(Dataset,dtype=int,drop_first=True)

# %%
Dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
Independent=Dataset[['age', 'bmi', 'children',  'sex_male', 'smoker_yes']]
Dependent=Dataset[['charges']]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
Independent=sc.fit_transform(Independent)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
Param_grid={'criterion':['squared_error','absolute_error','friedman_mse','poisson'],
            'max_features': ['sqrt','log2',None],
            'splitter':['best','random']}

# %%
grid = GridSearchCV(DecisionTreeRegressor(), Param_grid, refit = True, verbose= 3,n_jobs=-1)
grid.fit(Independent,Dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
grid_Pred=grid.predict(Independent)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'best'}:

# %%
from sklearn.metrics import r2_score
r_score=r2_score(grid_Pred,Dependent)
print(r_score)
# Out:
# 0.9986653772918882

# %%
table=pd.DataFrame.from_dict(re)
print(table)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.014123      0.014389         0.003930        0.002253
# 1        0.005297      0.004265         0.003708        0.003419
# 2        0.006228      0.002832         0.004023        0.003036
# 3        0.004792      0.002614         0.000000        0.000000
# 4        0.008658      0.007583         0.003928        0.006055
# 5        0.004193      0.004265         0.002316        0.004631
# 6        0.032603      0.006758         0.002685        0.001794
# 7        0.027626      0.002760         0.002342        0.003006
# 8        0.046076      0.015415         0.004329        0.004754
# 9        0.022695      0.004293         0.004065        0.005077
# 10       0.060912      0.004412         0.000908        0.001123
# 11       0.069140      0.011644         0.001614        0.001029
# 12       0.009558      0.001205         0.001007        0.001274
# 13       0.001612      0.001507         0.012775        0.018718
# 14       0.010907      0.002053         0.003762        0.003711
# 15       0.007356      0.002294         0.001870        0.002219
# 16       0.008241      0.001473         0.004591        0.003297
# 17       0.008086      0.004824         0.001822        0.001858
# 18       0.007161      0.002682         0.003573        0.002950
# 19       0.010041      0.006557         0.003025        0.004805
# 20       0.005902      0.001931         0.001776        0.002663
# 21       0.006247      0.001745         0.001406        0.001722
# 22       0.011753      0.001543         0.002293        0.001287
# 23       0.005759      0.001300         0.000961        0.001249
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4    squared_error               None           best
# 5    squared_error               None         random
# 6   absolute_error               sqrt           best
# 7   absolute_error               sqrt         random
# 8   absolute_error               log2           best
# 9   absolute_error               log2         random
# 10  absolute_error               None           best
# 11  absolute_error               None         random
# 12    friedman_mse               sqrt           best
# 13    friedman_mse               sqrt         random
# 14    friedman_mse               log2           best
# 15    friedman_mse               log2         random
# 16    friedman_mse               None           best
# 17    friedman_mse               None         random
# 18         poisson               sqrt           best
# 19         poisson               sqrt         random
# 20         poisson               log2           best
# 21         poisson               log2         random
# 22         poisson               None           best
# 23         poisson               None         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.806527
# 1   {'criterion': 'squared_error', 'max_features':...           0.553833
# 2   {'criterion': 'squared_error', 'max_features':...           0.725050
# 3   {'criterion': 'squared_error', 'max_features':...           0.648596
# 4   {'criterion': 'squared_error', 'max_features':...           0.735468
# 5   {'criterion': 'squared_error', 'max_features':...           0.717688
# 6   {'criterion': 'absolute_error', 'max_features'...           0.704906
# 7   {'criterion': 'absolute_error', 'max_features'...           0.634524
# 8   {'criterion': 'absolute_error', 'max_features'...           0.684542
# 9   {'criterion': 'absolute_error', 'max_features'...           0.694023
# 10  {'criterion': 'absolute_error', 'max_features'...           0.737518
# 11  {'criterion': 'absolute_error', 'max_features'...           0.700434
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.742683
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.706367
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.698087
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.669432
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.730219
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.703503
# 18  {'criterion': 'poisson', 'max_features': 'sqrt...           0.621840
# 19  {'criterion': 'poisson', 'max_features': 'sqrt...           0.708214
# 20  {'criterion': 'poisson', 'max_features': 'log2...           0.725784
# 21  {'criterion': 'poisson', 'max_features': 'log2...           0.732269
# 22  {'criterion': 'poisson', 'max_features': None,...           0.746631
# 23  {'criterion': 'poisson', 'max_features': None,...           0.729169
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.628706           0.760410           0.738213
# 1            0.661900           0.641416           0.655050
# 2            0.644535           0.745560           0.611594
# 3            0.470838           0.651561           0.588907
# 4            0.647562           0.742575           0.700346
# 5            0.639937           0.720007           0.751913
# 6            0.465782           0.674360           0.713379
# 7            0.570477           0.702220           0.698103
# 8            0.638937           0.634884           0.604551
# 9            0.670393           0.706564           0.736358
# 10           0.625446           0.697337           0.722215
# 11           0.663623           0.755657           0.769873
# 12           0.594524           0.794493           0.703656
# 13           0.500603           0.625727           0.696793
# 14           0.598345           0.737071           0.664047
# 15           0.579090           0.680013           0.693908
# 16           0.642389           0.730326           0.709476
# 17           0.604447           0.717371           0.686572
# 18           0.570700           0.774747           0.686382
# 19           0.477384           0.694368           0.683326
# 20           0.667692           0.666667           0.728791
# 21           0.464678           0.690164           0.705671
# 22           0.658002           0.763934           0.715916
# 23           0.638050           0.674049           0.724454
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.757334         0.738238        0.059189                1
# 1            0.688986         0.640237        0.045896               22
# 2            0.703216         0.685991        0.050248               13
# 3            0.677422         0.607465        0.074218               24
# 4            0.693428         0.703876        0.034025                6
# 5            0.679408         0.701791        0.038532                7
# 6            0.653914         0.642468        0.090877               21
# 7            0.663871         0.653839        0.048421               17
# 8            0.736797         0.659942        0.046150               16
# 9            0.650645         0.691597        0.029530               12
# 10           0.743956         0.705294        0.043031                5
# 11           0.746450         0.727207        0.039395                2
# 12           0.718597         0.710791        0.065807                4
# 13           0.667740         0.639446        0.074877               23
# 14           0.770748         0.693660        0.059680               10
# 15           0.621931         0.648875        0.042464               19
# 16           0.694064         0.701295        0.032461                8
# 17           0.687128         0.679804        0.039372               14
# 18           0.729736         0.676681        0.073165               15
# 19           0.666513         0.645961        0.085388               20
# 20           0.681699         0.694127        0.027609                9
# 21           0.658009         0.650158        0.095801               18
# 22           0.704904         0.717878        0.036620                3
# 23           0.693718         0.691888        0.033676               11

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[48549.17835]

# %%
import pickle
FileName="Finalize_Advance_model.sav"
pickle.dump(grid,open(FileName,"wb"))

# %%
loaded_model=pickle.load(open("Finalize_Advance_model.sav","rb"))
pre_int=sc.transform([[36,30,2,0,1]])
result=loaded_model.predict(pre_int)
print(result)
# Out:
# [20984.0936]
# c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
