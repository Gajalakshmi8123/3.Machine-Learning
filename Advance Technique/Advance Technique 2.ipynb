# %%
import pandas as pd

# %%
Dataset=pd.read_csv('insurance_pre.csv')

# %%
Dataset.head()
# Out:
#    age     sex     bmi  children smoker      charges
# 0   19  female  27.900         0    yes  16884.92400
# 1   18    male  33.770         1     no   1725.55230
# 2   28    male  33.000         3     no   4449.46200
# 3   33    male  22.705         0     no  21984.47061
# 4   32    male  28.880         0     no   3866.85520

# %%
Dataset=pd.get_dummies(Dataset,dtype=int,drop_first=True)

# %%
Dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
Independent=Dataset[['age', 'bmi', 'children',  'sex_male', 'smoker_yes']]
Dependent=Dataset[['charges']]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
Independent=sc.fit_transform(Independent)

# %%
scy=StandardScaler()
Dependent=scy.fit_transform(Dependent)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
Param_grid={'criterion':['squared_error','absolute_error','friedman_mse','poisson'],
            'max_features': ['sqrt','log2',None],
            'splitter':['best','random']}

# %%
grid = GridSearchCV(DecisionTreeRegressor(), Param_grid, refit = True, verbose= 3,n_jobs=-1)
grid.fit(Independent,Dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 30 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_classes.py", line 1377, in fit
#     super()._fit(
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_classes.py", line 269, in _fit
#     raise ValueError(
# ValueError: Some value(s) of y are negative which is not allowed for Poisson regression.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.64893246 0.65639689 0.6701891  0.6848987  0.71236285 0.70335401
#  0.64016775 0.60166168 0.61969906 0.60821626 0.70124594 0.69521351
#  0.69440707 0.61277329 0.69057218 0.63820526 0.69600148 0.68260347
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
grid_Pred=grid.predict(Independent)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'squared_error', 'max_features': None, 'splitter': 'best'}:

# %%
from sklearn.metrics import r2_score
r_score=r2_score(grid_Pred,Dependent)
print(r_score)
# Out:
# 0.9986653772918882

# %%
table=pd.DataFrame.from_dict(re)
print(table)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.004175      0.002593         0.001182        0.001290
# 1        0.005534      0.003544         0.000000        0.000000
# 2        0.004757      0.003992         0.000522        0.001044
# 3        0.001511      0.001915         0.001792        0.002217
# 4        0.007092      0.002684         0.000000        0.000000
# 5        0.005008      0.002362         0.000917        0.001125
# 6        0.021404      0.009009         0.000000        0.000000
# 7        0.020118      0.002686         0.001263        0.001907
# 8        0.030256      0.005155         0.000634        0.001268
# 9        0.023831      0.005311         0.002519        0.003902
# 10       0.066278      0.003588         0.000889        0.001089
# 11       0.046758      0.003300         0.004971        0.005745
# 12       0.007202      0.004891         0.002001        0.004002
# 13       0.000000      0.000000         0.000000        0.000000
# 14       0.005834      0.002380         0.001299        0.002054
# 15       0.001886      0.001660         0.000000        0.000000
# 16       0.007698      0.003767         0.002016        0.002213
# 17       0.004882      0.002447         0.000804        0.000985
# 18       0.000705      0.001177         0.000000        0.000000
# 19       0.000662      0.000882         0.000000        0.000000
# 20       0.000949      0.000783         0.000000        0.000000
# 21       0.000829      0.000538         0.000000        0.000000
# 22       0.001115      0.000384         0.000000        0.000000
# 23       0.001053      0.000743         0.000000        0.000000
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4    squared_error               None           best
# 5    squared_error               None         random
# 6   absolute_error               sqrt           best
# 7   absolute_error               sqrt         random
# 8   absolute_error               log2           best
# 9   absolute_error               log2         random
# 10  absolute_error               None           best
# 11  absolute_error               None         random
# 12    friedman_mse               sqrt           best
# 13    friedman_mse               sqrt         random
# 14    friedman_mse               log2           best
# 15    friedman_mse               log2         random
# 16    friedman_mse               None           best
# 17    friedman_mse               None         random
# 18         poisson               sqrt           best
# 19         poisson               sqrt         random
# 20         poisson               log2           best
# 21         poisson               log2         random
# 22         poisson               None           best
# 23         poisson               None         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.717102
# 1   {'criterion': 'squared_error', 'max_features':...           0.688827
# 2   {'criterion': 'squared_error', 'max_features':...           0.621228
# 3   {'criterion': 'squared_error', 'max_features':...           0.732068
# 4   {'criterion': 'squared_error', 'max_features':...           0.736344
# 5   {'criterion': 'squared_error', 'max_features':...           0.685496
# 6   {'criterion': 'absolute_error', 'max_features'...           0.697037
# 7   {'criterion': 'absolute_error', 'max_features'...           0.585852
# 8   {'criterion': 'absolute_error', 'max_features'...           0.573709
# 9   {'criterion': 'absolute_error', 'max_features'...           0.626105
# 10  {'criterion': 'absolute_error', 'max_features'...           0.753558
# 11  {'criterion': 'absolute_error', 'max_features'...           0.640137
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.709857
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.593173
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.768961
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.710396
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.715792
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.762590
# 18  {'criterion': 'poisson', 'max_features': 'sqrt...                NaN
# 19  {'criterion': 'poisson', 'max_features': 'sqrt...                NaN
# 20  {'criterion': 'poisson', 'max_features': 'log2...                NaN
# 21  {'criterion': 'poisson', 'max_features': 'log2...                NaN
# 22  {'criterion': 'poisson', 'max_features': None,...                NaN
# 23  {'criterion': 'poisson', 'max_features': None,...                NaN
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.623171           0.488667           0.713186
# 1            0.523008           0.763699           0.676588
# 2            0.566548           0.726701           0.693848
# 3            0.582947           0.690364           0.666526
# 4            0.666145           0.739620           0.734249
# 5            0.647725           0.733850           0.743974
# 6            0.562640           0.671189           0.591678
# 7            0.533374           0.623544           0.641058
# 8            0.526243           0.692117           0.671214
# 9            0.486093           0.652050           0.684835
# 10           0.575981           0.691088           0.720611
# 11           0.627097           0.750362           0.732880
# 12           0.625704           0.757432           0.716783
# 13           0.485769           0.714128           0.597430
# 14           0.503236           0.689763           0.725010
# 15           0.554752           0.623226           0.661485
# 16           0.655610           0.713452           0.707735
# 17           0.552572           0.693415           0.744022
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20                NaN                NaN                NaN
# 21                NaN                NaN                NaN
# 22                NaN                NaN                NaN
# 23                NaN                NaN                NaN
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.702538         0.648932        0.087176               12
# 1            0.629863         0.656397        0.079334               11
# 2            0.742620         0.670189        0.066540               10
# 3            0.752588         0.684899        0.059276                8
# 4            0.685456         0.712363        0.030519                1
# 5            0.705726         0.703354        0.034639                2
# 6            0.678295         0.640168        0.052938               13
# 7            0.624480         0.601662        0.038638               18
# 8            0.635211         0.619699        0.061624               15
# 9            0.591999         0.608216        0.068248               17
# 10           0.764991         0.701246        0.067778                3
# 11           0.725591         0.695214        0.051100                5
# 12           0.662259         0.694407        0.045750                6
# 13           0.673365         0.612773        0.078350               16
# 14           0.765891         0.690572        0.098081                7
# 15           0.641167         0.638205        0.050894               14
# 16           0.687419         0.696001        0.022535                4
# 17           0.660418         0.682603        0.074414                9
# 18                NaN              NaN             NaN               19
# 19                NaN              NaN             NaN               19
# 20                NaN              NaN             NaN               19
# 21                NaN              NaN             NaN               19
# 22                NaN              NaN             NaN               19
# 23                NaN              NaN             NaN               19

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[4.17166316]

# %%
import pickle
FileName="Finalize_Advance_model.sav"
pickle.dump(grid,open(FileName,"wb"))

# %%
loaded_model=pickle.load(open("Finalize_Advance_model.sav","rb"))
pre_int=sc.transform([[36,30,2,0,1]])
result=loaded_model.predict(pre_int)
print(result)
# Out:
# [0.61753551]
# c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
pre_output=scy.inverse_transform([result])
print(pre_output)
# Out:
# [[20745.9891]]
