# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Dataset=pd.read_csv('Spectral_cluster.csv')

# %%
Dataset.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
#    Cluster_group
# 0              4
# 1              2
# 2              4
# 3              2
# 4              4

# %%
X=Dataset.iloc[:,[3,4]].values

# %%
from sklearn.cluster import spectral_clustering
from sklearn.metrics import pairwise_distances

# Assuming X is a 2D array with two features
# Compute an affinity matrix from the data
affinity_matrix = pairwise_distances(X)

# Perform spectral clustering
Y_SC = spectral_clustering(affinity=affinity_matrix, n_clusters=2, assign_labels='discretize')

# Plot the clustering result
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(X[:, 0], X[:, 1], c=Y_SC, cmap='viridis', marker='o', edgecolor='k')
plt.title('Spectral Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
