# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Dataset=pd.read_csv('cluster.csv')

# %%
Dataset.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
#    Cluster_group
# 0              4
# 1              2
# 2              4
# 3              2
# 4              4

# %%
X=Dataset.iloc[:,[3,4]].values

# %%
from sklearn.cluster import OPTICS
op=OPTICS(min_samples=2).fit(X)
Y_op=op.fit_predict(X)
# Out:
# c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\cluster\_optics.py:1081: RuntimeWarning: divide by zero encountered in divide
#   ratio = reachability_plot[:-1] / reachability_plot[1:]
# c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\cluster\_optics.py:1081: RuntimeWarning: divide by zero encountered in divide
#   ratio = reachability_plot[:-1] / reachability_plot[1:]

# %%
Y_op
# Out:
# array([ 0, -1, 35, 29,  0, 29, 35, 46, 35, -1, 34, 46, 34, 30, 34, 30,  1,
#        -1,  2, 46,  1, 28, 36, 28, 33, 31,  2, -1,  2, 31, 36, 27, 36, 32,
#        33, 31, 33, 27,  3, 27,  4, 32,  4, 13,  3, -1, -1, -1,  5,  5,  9,
#        13,  9, 13,  6,  5,  8,  6,  8,  6, 10, 10,  8, 12,  8, 12,  8,  7,
#        12,  7, 11, -1, -1, 11, 14, 16, 16, 14, 16, 15, 16, 16, 15, -1, 16,
#        14, 18, 17, 18, -1, 17, -1, 21, -1, 23, -1, -1, 21, 23, 21, 23, 20,
#        -1, 19, 19, 23, -1, 22, 23, 20, -1, 19, -1, 22, -1, -1, -1, 24, -1,
#        24, 24, -1, 24, 51, -1, 48, 25, 51, 39, 48, 39, 48, 25, 47, 40, 51,
#        40, 47, -1, 47, 40, 51, 26, 51, -1, 51, 26, 49, 37, 51, 38, 51, 37,
#        50, 38, 51, 41, 50, 41, 49, 26, -1, 41, 51, 44, 54, 42, 52, 44, 54,
#        42, 54, 42, 52, 42, -1, 42, 54, 42, 53, 45, 53, 42, 53, 45, -1, 43,
#        55, 42, 53, 43, 55, 56, -1, 56, 57, -1, 57, -1, 57])

# %%
supervised=pd.DataFrame(Dataset)

# %%
supervised['Cluster_group']=Y_op

# %%
print(supervised)
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      Cluster_group
# 0                0
# 1               -1
# 2               35
# ...

# %%
supervised.to_csv("Optics_cluster.csv",index=False)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming X is a 2D array with two features
plt.figure(figsize=(10, 6))

# Plotting the points with their assigned cluster labels
plt.scatter(X[:, 0], X[:, 1], c=Y_op, cmap='viridis', marker='o', edgecolor='k')

# Adding labels and title
plt.title('OPTICS Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')

# Show the plot
plt.show()
