# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Dataset=pd.read_csv('cluster.csv')

# %%
Dataset.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
#    Cluster_group
# 0              2
# 1              3
# 2              2
# 3              3
# 4              2

# %%
X=Dataset.iloc[:,[3,4]].values

# %%
from sklearn.cluster import MeanShift

# Fit the MeanShift model
meanshift = MeanShift(bandwidth=13).fit(X)
Mean=meanshift.fit(X)

# %%
Mean
# Out:
# MeanShift(bandwidth=13)

# %%
supervised=pd.DataFrame(Dataset)

# %%
supervised['Cluster_group']=Mean

# %%
print(supervised)
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#                Cluster_group
# 0    MeanShift(bandwidth=13)
# 1    MeanShift(bandwidth=13)
# ...

# %%
supervised.to_csv("MeanShift_cluster.csv",index=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(data=supervised, x=supervised.columns[3], y=supervised.columns[4], palette='viridis', edgecolor='k')
plt.title('MeanShift Clustering Results')
plt.show()
# Out:
# C:\Users\Gajalakshmi G\AppData\Local\Temp\ipykernel_21672\1003676306.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=supervised, x=supervised.columns[3], y=supervised.columns[4],  palette='viridis', edgecolor='k')
