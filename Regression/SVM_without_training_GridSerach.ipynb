# %%
import pandas as pd

# %%
Dataset=pd.read_csv('insurance_pre.csv')

# %%
Dataset=pd.get_dummies(Dataset,dtype=int,drop_first=True)

# %%
Dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
Independent=Dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
Dependent=Dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf''poly','sigmoid','linear'],
'C':[10,100,1000,2000,3000],'gamma':['auto','scale']}

# %%
grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3,n_jobs=-1)
grid.fit(Independent,Dependent)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 50 fits failed out of a total of 150.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 12 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'kernel' parameter of SVR must be a str among {'poly', 'sigmoid', 'rbf', 'precomputed', 'linear'} or a callable. Got 'rbfpoly' instead.
#
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'kernel' parameter of SVR must be a str among {'sigmoid', 'poly', 'linear', 'rbf', 'precomputed'} or a callable. Got 'rbfpoly' instead.
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'kernel' parameter of SVR must be a str among {'sigmoid', 'precomputed', 'rbf', 'poly', 'linear'} or a callable. Got 'rbfpoly' instead.
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'kernel' parameter of SVR must be a str among {'poly', 'linear', 'precomputed', 'sigmoid', 'rbf'} or a callable. Got 'rbfpoly' instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'kernel' parameter of SVR must be a str among {'poly', 'precomputed', 'linear', 'sigmoid', 'rbf'} or a callable. Got 'rbfpoly' instead.
#
# --------------------------------------------------------------------------------
# 9 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'kernel' parameter of SVR must be a str among {'poly', 'sigmoid', 'precomputed', 'rbf', 'linear'} or a callable. Got 'rbfpoly' instead.
#
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'kernel' parameter of SVR must be a str among {'rbf', 'precomputed', 'linear', 'poly', 'sigmoid'} or a callable. Got 'rbfpoly' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [            nan -1.04753143e-01 -6.08619573e-03             nan
#  -1.07639026e-01 -6.08619573e-03             nan -1.04753143e-01
#   5.35224746e-01             nan -1.37843088e-01  5.35224746e-01
#              nan -1.04753143e-01  6.93778198e-01             nan
#  -2.21544064e+00  6.93778198e-01             nan -1.04753143e-01
#   6.86466559e-01             nan -7.78112551e+00  6.86466559e-01
#              nan -1.04753143e-01  6.73913747e-01             nan
#  -1.69838559e+01  6.73913747e-01]
#   warnings.warn(
# c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbfpoly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
grid_pred=grid.predict(Independent)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(grid_pred,Dependent)
print(r_score)
# Out:
# 0.6254740546405225

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}:

# %%
table=pd.DataFrame.from_dict(re)
print(table)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.002909      0.002936         0.000000        0.000000      10
# 1        0.095324      0.016819         0.029952        0.008797      10
# 2        0.143826      0.032879         0.023325        0.004500      10
# 3        0.005402      0.003958         0.000000        0.000000      10
# 4        0.153911      0.007939         0.035470        0.001886      10
# 5        0.131234      0.028021         0.027921        0.009552      10
# 6        0.003875      0.002433         0.000000        0.000000     100
# 7        0.108188      0.012774         0.030282        0.006606     100
# 8        0.253609      0.015354         0.020442        0.003168     100
# 9        0.003244      0.002697         0.000000        0.000000     100
# 10       0.169893      0.025610         0.042447        0.008293     100
# 11       0.277683      0.024497         0.023737        0.003931     100
# 12       0.002692      0.002194         0.000000        0.000000    1000
# 13       0.114525      0.015252         0.030183        0.004838    1000
# 14       1.012673      0.152273         0.022154        0.003021    1000
# 15       0.002007      0.003105         0.000000        0.000000    1000
# 16       0.189591      0.018798         0.050891        0.012879    1000
# 17       1.048191      0.239776         0.021569        0.001871    1000
# 18       0.002818      0.002526         0.000000        0.000000    2000
# 19       0.127333      0.010211         0.030087        0.005072    2000
# 20       1.792035      0.146511         0.021115        0.001002    2000
# 21       0.003684      0.002918         0.000000        0.000000    2000
# 22       0.144118      0.009167         0.036488        0.003853    2000
# 23       1.820931      0.444945         0.021586        0.001833    2000
# 24       0.004207      0.002282         0.000000        0.000000    3000
# 25       0.107600      0.015048         0.033662        0.009771    3000
# 26       2.654964      0.935241         0.014830        0.006179    3000
# 27       0.002212      0.002053         0.000000        0.000000    3000
# 28       0.160590      0.019309         0.038822        0.004124    3000
# 29       3.142651      0.620050         0.023978        0.008713    3000
#
#    param_gamma param_kernel  \
# 0         auto      rbfpoly
# 1         auto      sigmoid
# 2         auto       linear
# 3        scale      rbfpoly
# 4        scale      sigmoid
# 5        scale       linear
# 6         auto      rbfpoly
# 7         auto      sigmoid
# 8         auto       linear
# 9        scale      rbfpoly
# 10       scale      sigmoid
# 11       scale       linear
# 12        auto      rbfpoly
# 13        auto      sigmoid
# 14        auto       linear
# 15       scale      rbfpoly
# 16       scale      sigmoid
# 17       scale       linear
# 18        auto      rbfpoly
# 19        auto      sigmoid
# 20        auto       linear
# 21       scale      rbfpoly
# 22       scale      sigmoid
# 23       scale       linear
# 24        auto      rbfpoly
# 25        auto      sigmoid
# 26        auto       linear
# 27       scale      rbfpoly
# 28       scale      sigmoid
# 29       scale       linear
#
#                                                params  split0_test_score  \
# 0     {'C': 10, 'gamma': 'auto', 'kernel': 'rbfpoly'}                NaN
# 1     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 2      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}          -0.018943
# 3    {'C': 10, 'gamma': 'scale', 'kernel': 'rbfpoly'}                NaN
# 4    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.116743
# 5     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}          -0.018943
# 6    {'C': 100, 'gamma': 'auto', 'kernel': 'rbfpoly'}                NaN
# 7    {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 8     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.559313
# 9   {'C': 100, 'gamma': 'scale', 'kernel': 'rbfpoly'}                NaN
# 10  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.142455
# 11   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.559313
# 12  {'C': 1000, 'gamma': 'auto', 'kernel': 'rbfpoly'}                NaN
# 13  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 14   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.736398
# 15  {'C': 1000, 'gamma': 'scale', 'kernel': 'rbfpo...                NaN
# 16  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...          -2.043140
# 17  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.736398
# 18  {'C': 2000, 'gamma': 'auto', 'kernel': 'rbfpoly'}                NaN
# 19  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 20   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.682349
# 21  {'C': 2000, 'gamma': 'scale', 'kernel': 'rbfpo...                NaN
# 22  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -7.209317
# 23  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.682349
# 24  {'C': 3000, 'gamma': 'auto', 'kernel': 'rbfpoly'}                NaN
# 25  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 26   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.677778
# 27  {'C': 3000, 'gamma': 'scale', 'kernel': 'rbfpo...                NaN
# 28  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...         -15.561853
# 29  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.677778
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1           -0.113567          -0.081608          -0.106067
# 2            0.029886           0.022167           0.003112
# 3                 NaN                NaN                NaN
# 4           -0.119312          -0.085214          -0.108210
# 5            0.029886           0.022167           0.003112
# 6                 NaN                NaN                NaN
# 7           -0.113567          -0.081608          -0.106067
# 8            0.521798           0.547691           0.538805
# 9                 NaN                NaN                NaN
# 10          -0.160831          -0.117544          -0.137984
# 11           0.521798           0.547691           0.538805
# 12                NaN                NaN                NaN
# 13          -0.113567          -0.081608          -0.106067
# 14           0.675162           0.680002           0.699377
# 15                NaN                NaN                NaN
# 16          -2.686121          -2.194563          -2.210858
# 17           0.675162           0.680002           0.699377
# 18                NaN                NaN                NaN
# 19          -0.113567          -0.081608          -0.106067
# 20           0.630642           0.750714           0.646368
# 21                NaN                NaN                NaN
# 22          -9.282940          -7.776578          -7.745074
# 23           0.630642           0.750714           0.646368
# 24                NaN                NaN                NaN
# 25          -0.113567          -0.081608          -0.106067
# 26           0.626814           0.732806           0.633479
# 27                NaN                NaN                NaN
# 28         -20.498908         -17.095474         -16.750877
# 29           0.626814           0.732806           0.633479
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               21
# 1           -0.107195        -0.104753        0.012107               11
# 2           -0.066653        -0.006086        0.034672                9
# 3                 NaN              NaN             NaN               21
# 4           -0.108716        -0.107639        0.012029               16
# 5           -0.066653        -0.006086        0.034672                9
# 6                 NaN              NaN             NaN               21
# 7           -0.107195        -0.104753        0.012107               11
# 8            0.508518         0.535225        0.018122                7
# 9                 NaN              NaN             NaN               21
# 10          -0.130402        -0.137843        0.014263               17
# 11           0.508518         0.535225        0.018122                7
# 12                NaN              NaN             NaN               21
# 13          -0.107195        -0.104753        0.012107               11
# 14           0.677952         0.693778        0.022955                1
# 15                NaN              NaN             NaN               21
# 16          -1.942521        -2.215441        0.255409               18
# 17           0.677952         0.693778        0.022955                1
# 18                NaN              NaN             NaN               21
# 19          -0.107195        -0.104753        0.012107               11
# 20           0.722261         0.686467        0.045056                3
# 21                NaN              NaN             NaN               21
# 22          -6.891719        -7.781126        0.821557               19
# 23           0.722261         0.686467        0.045056                3
# 24                NaN              NaN             NaN               21
# 25          -0.107195        -0.104753        0.012107               11
# 26           0.698692         0.673914        0.039876                5
# 27                NaN              NaN             NaN               21
# 28         -15.012168       -16.983856        1.914783               20
# 29           0.698692         0.673914        0.039876                5

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[5142.51021397]
# c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
