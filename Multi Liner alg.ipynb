# %%
import pandas as pd
Dataset=pd.read_csv("Performance.csv")
print(Dataset.head(10))
# Out:
#    Employee ID  Performance_Rating  Years_of_Experience   Salary
# 0           51                   3                    4  55000.0
# 1           52                   4                    7  72000.0
# 2           53                   2                    2  48000.0
# 3           54                   5                    9  85000.0
# 4           55                   3                    6  62000.0
# 5           56                   4                    5  60000.0
# 6           57                   5                    8  78000.0
# 7           58                   3                    3  52000.0
# 8           59                   4                    6  65000.0
# 9           60                   2                    1  45000.0

# %%
Independent=Dataset[["Performance_Rating","Years_of_Experience"]]
Dependent=Dataset[["Salary"]]
print(Independent.head(10))
print(Dependent.head(10))
# Out:
#    Performance_Rating  Years_of_Experience
# 0                   3                    4
# 1                   4                    7
# 2                   2                    2
# 3                   5                    9
# 4                   3                    6
# 5                   4                    5
# 6                   5                    8
# 7                   3                    3
# 8                   4                    6
# 9                   2                    1
#     Salary
# 0  55000.0
# 1  72000.0
# 2  48000.0
# 3  85000.0
# 4  62000.0
# 5  60000.0
# 6  78000.0
# 7  52000.0
# 8  65000.0
# 9  45000.0

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(Independent,Dependent,test_size=0.30,random_state=40)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVC
regressor=LinearRegression()
regressor.fit(X_train,Y_train)
svc_classifier = SVC()
svc_classifier.fit(X_train, Y_train)
# Out:
# c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC()

# %%
weight=regressor.coef_
print(weight)
Bias=regressor.intercept_
print(Bias)
# Out:
# [[ 433.94396552 4913.90086207]]
# [36313.79310345]

# %%
Biassvc=svc_classifier.intercept_
print(Biassvc)
# Out:
# [-1.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00 -2.91304260e-01  0.00000000e+00  0.00000000e+00
#  -1.61874034e-01 -1.22854084e-01  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -2.79644169e-02  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -7.20090838e-03  0.00000000e+00
#  -7.82008632e-04  0.00000000e+00 -1.22950922e-04 -1.51050217e-05
#   7.18577325e-01  7.18577325e-01  7.18577325e-01  4.73533079e-01
#  -6.61929995e-02  4.73533079e-01  4.73533079e-01 -4.28910491e-02
#  -2.62071788e-02  2.65097082e-01  1.14429200e-01  1.14429200e-01
#   1.14429200e-01  2.44036530e-02  1.14429200e-01  1.14429200e-01
#   7.56005722e-02  2.94872065e-02  6.03521729e-02  2.99362380e-02
#   5.84703893e-02  2.98964013e-02  2.98851827e-02  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -8.83964181e-01  0.00000000e+00
#   0.00000000e+00 -6.33168250e-01 -6.10574603e-01  0.00000000e+00
# ...

# %%
Y_pred=regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(Y_pred,Y_test)
print(r_score)
# Out:
# 0.9705356119333115

# %%
Y_pred=svc_classifier.predict(X_test)
from sklearn.metrics import r2_score
r_score=r2_score(Y_pred,Y_test)
print(r_score)
# Out:
# 0.9688809339787658

# %%
import pickle
Filename="Final_mdel_multilinear.sav"
pickle.dump(regressor,open(Filename,"wb"))

# %%
loaded_model=pickle.load(open("Final_mdel_multilinear.sav",'rb'))
Result=loaded_model.predict([[5,18]])
print(Result)

# %%
loaded_model=pickle.load(open("Final_mdel_multilinear.sav","rb"))
Result=loaded_model.predict([[4,13]])
print(Result)

# %%
loaded_model=pickle.load(open("Final_mdel_multilinear.sav","rb"))
Result=loaded_model.predict([[0,0]])
print(Result)

# %%
import matplotlib.pyplot as plt
x=Independent
y=Dependent
plt.figure(figsize=(10, 5))  # Optional: Set the figure size (width, height)
plt.plot(x, y, marker='o', linestyle='-', color='b', label='Linear Plot')

# Customize the plot (optional)
plt.title('Linear Graph Example')  # Set the title of the plot
plt.xlabel('X-axis')              # Set the label for the x-axis
plt.ylabel('Y-axis')              # Set the label for the y-axis
plt.grid(True)                    # Show grid
plt.legend()                      # Show legend (uses label='...' from plt.plot)

# Show the plot
plt.show()
