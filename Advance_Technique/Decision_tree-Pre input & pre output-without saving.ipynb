# %%
import pandas as pd

# %%
Dataset=pd.read_csv('insurance_pre.csv')

# %%
print(Dataset.head())
# Out:
#    age     sex     bmi  children smoker      charges
# 0   19  female  27.900         0    yes  16884.92400
# 1   18    male  33.770         1     no   1725.55230
# 2   28    male  33.000         3     no   4449.46200
# 3   33    male  22.705         0     no  21984.47061
# 4   32    male  28.880         0     no   3866.85520

# %%
Dataset=pd.get_dummies(Dataset,dtype=int,drop_first=True)

# %%
Dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
Independent=Dataset[['age', 'bmi', 'children',  'sex_male', 'smoker_yes']]
Dependent=Dataset[['charges']]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
Independent=sc.fit_transform(Independent)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
Param_grid={'criterion':['squared_error','absolute_error','friedman_mse','poisson'],
            'max_features': ['sqrt','log2',None],
            'splitter':['best','random']}

# %%
grid = GridSearchCV(DecisionTreeRegressor(), Param_grid, refit = True, verbose= 3,n_jobs=-1)
grid.fit(Independent,Dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
grid_Pred=grid.predict(Independent)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'absolute_error', 'max_features': None, 'splitter': 'best'}:

# %%
from sklearn.metrics import r2_score
r_score=r2_score(grid_Pred,Dependent)
print(r_score)
# Out:
# 0.9986653772918882

# %%
table=pd.DataFrame.from_dict(re)
print(table)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.005990      0.004891         0.006506        0.005334
# 1        0.003649      0.004869         0.005586        0.003748
# 2        0.003483      0.002455         0.002559        0.002603
# 3        0.003587      0.002196         0.000321        0.000642
# 4        0.008947      0.001390         0.002488        0.002321
# 5        0.003559      0.003299         0.004752        0.003031
# 6        0.024987      0.008900         0.003043        0.004404
# 7        0.022578      0.004199         0.000655        0.001311
# 8        0.029949      0.005544         0.002043        0.004085
# 9        0.021988      0.001283         0.008545        0.008064
# 10       0.065397      0.011414         0.002211        0.003006
# 11       0.044747      0.003394         0.005747        0.003811
# 12       0.005648      0.004670         0.003624        0.003689
# 13       0.007235      0.003728         0.002414        0.002952
# 14       0.003772      0.003696         0.005564        0.002680
# 15       0.003416      0.004232         0.003619        0.003259
# 16       0.005769      0.003297         0.003934        0.002747
# 17       0.008461      0.002429         0.000316        0.000632
# 18       0.007402      0.001524         0.003130        0.002638
# 19       0.005277      0.004088         0.005058        0.002426
# 20       0.008289      0.005690         0.004005        0.002727
# 21       0.005024      0.002527         0.002517        0.002527
# 22       0.008077      0.002477         0.002441        0.003420
# 23       0.011211      0.001832         0.000711        0.000885
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4    squared_error               None           best
# 5    squared_error               None         random
# 6   absolute_error               sqrt           best
# 7   absolute_error               sqrt         random
# 8   absolute_error               log2           best
# 9   absolute_error               log2         random
# 10  absolute_error               None           best
# 11  absolute_error               None         random
# 12    friedman_mse               sqrt           best
# 13    friedman_mse               sqrt         random
# 14    friedman_mse               log2           best
# 15    friedman_mse               log2         random
# 16    friedman_mse               None           best
# 17    friedman_mse               None         random
# 18         poisson               sqrt           best
# 19         poisson               sqrt         random
# 20         poisson               log2           best
# 21         poisson               log2         random
# 22         poisson               None           best
# 23         poisson               None         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.650014
# 1   {'criterion': 'squared_error', 'max_features':...           0.749386
# 2   {'criterion': 'squared_error', 'max_features':...           0.718434
# 3   {'criterion': 'squared_error', 'max_features':...           0.770977
# 4   {'criterion': 'squared_error', 'max_features':...           0.735064
# 5   {'criterion': 'squared_error', 'max_features':...           0.665475
# 6   {'criterion': 'absolute_error', 'max_features'...           0.745830
# 7   {'criterion': 'absolute_error', 'max_features'...           0.696688
# 8   {'criterion': 'absolute_error', 'max_features'...           0.668584
# 9   {'criterion': 'absolute_error', 'max_features'...           0.753768
# 10  {'criterion': 'absolute_error', 'max_features'...           0.749588
# 11  {'criterion': 'absolute_error', 'max_features'...           0.694090
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.703079
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.651180
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.715163
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.700946
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.726639
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.753449
# 18  {'criterion': 'poisson', 'max_features': 'sqrt...           0.786490
# 19  {'criterion': 'poisson', 'max_features': 'sqrt...           0.633783
# 20  {'criterion': 'poisson', 'max_features': 'log2...           0.699814
# 21  {'criterion': 'poisson', 'max_features': 'log2...           0.581169
# 22  {'criterion': 'poisson', 'max_features': None,...           0.737041
# 23  {'criterion': 'poisson', 'max_features': None,...           0.648739
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.666221           0.722101           0.663607
# 1            0.504292           0.744101           0.642564
# 2            0.560048           0.565513           0.734374
# 3            0.596706           0.738560           0.683545
# 4            0.642801           0.727060           0.694048
# 5            0.643714           0.644034           0.678194
# 6            0.652175           0.597356           0.713996
# 7            0.537398           0.694543           0.555502
# 8            0.483989           0.745797           0.683207
# 9            0.679660           0.634308           0.334511
# 10           0.658021           0.726472           0.720505
# 11           0.602765           0.726609           0.705756
# 12           0.629531           0.719768           0.692363
# 13           0.599073           0.713410           0.665867
# 14           0.602839           0.755399           0.752353
# 15           0.556258           0.615132           0.723997
# 16           0.643637           0.736007           0.732917
# 17           0.647720           0.718081           0.688237
# 18           0.588278           0.764294           0.716314
# 19           0.540259           0.709780           0.708854
# 20           0.683159           0.769118           0.714867
# 21           0.532520           0.670325           0.678817
# 22           0.651344           0.772202           0.735947
# 23           0.570830           0.669252           0.698712
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.655013         0.671391        0.026016               13
# 1            0.663328         0.660734        0.089017               17
# 2            0.732182         0.662110        0.081305               16
# 3            0.658803         0.689718        0.061047               10
# 4            0.697265         0.699248        0.032476                8
# 5            0.698294         0.665942        0.020838               15
# 6            0.695102         0.680892        0.051609               12
# 7            0.686868         0.634200        0.071950               22
# 8            0.673901         0.651096        0.088034               20
# 9            0.573977         0.595245        0.142980               24
# 10           0.752110         0.721339        0.034003                1
# 11           0.732998         0.692443        0.046977                9
# 12           0.681947         0.685338        0.030579               11
# 13           0.702074         0.666321        0.040614               14
# 14           0.727108         0.710572        0.055957                3
# 15           0.624547         0.644176        0.060914               21
# 16           0.697162         0.707272        0.034670                5
# 17           0.714203         0.704338        0.035108                7
# 18           0.678879         0.706851        0.070105                6
# 19           0.679363         0.654408        0.063417               18
# 20           0.678257         0.709043        0.032698                4
# 21           0.694269         0.631420        0.063272               23
# 22           0.707637         0.720834        0.040331                2
# 23           0.672871         0.652081        0.043622               19

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[36580.28216]

# %%
import pickle
FileName="Decision_Tree_final.sav"
pickle.dump(grid,open(FileName,"wb"))

# %%
loaded_model=pickle.load(open("Decision_Tree_final.sav","rb"))
pre_int=sc.transform([[36,30,2,0,1]])
result=loaded_model.predict(pre_int)
print(result)
# Out:
# [20984.0936]
# c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
