# %%
import pandas as pd

# %%
Dataset=pd.read_csv('insurance_pre.csv')

# %%
Dataset.head()
# Out:
#    age     sex     bmi  children smoker      charges
# 0   19  female  27.900         0    yes  16884.92400
# 1   18    male  33.770         1     no   1725.55230
# 2   28    male  33.000         3     no   4449.46200
# 3   33    male  22.705         0     no  21984.47061
# 4   32    male  28.880         0     no   3866.85520

# %%
Dataset=pd.get_dummies(Dataset,dtype=int,drop_first=True)

# %%
Dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
Independent=Dataset[['age', 'bmi', 'children',  'sex_male', 'smoker_yes']]
Dependent=Dataset[['charges']]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
Independent=sc.fit_transform(Independent)

# %%
scy=StandardScaler()
Dependent=scy.fit_transform(Dependent)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
Param_grid={'criterion':['squared_error','absolute_error','friedman_mse','poisson'],
            'max_features': ['sqrt','log2',None],
            'splitter':['best','random']}

# %%
import pickle
FileName="scx.pkl"
pickle.dump(sc,open(FileName,"wb"))

# %%
import pickle
FileName="scy.pkl"
pickle.dump(scy,open(FileName,'wb'))

# %%
grid = GridSearchCV(DecisionTreeRegressor(), Param_grid, refit = True, verbose= 3,n_jobs=-1)
grid.fit(Independent,Dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 30 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_classes.py", line 1377, in fit
#     super()._fit(
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_classes.py", line 269, in _fit
#     raise ValueError(
# ValueError: Some value(s) of y are negative which is not allowed for Poisson regression.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.63793411 0.64179093 0.71043444 0.64483069 0.69997583 0.68164916
#  0.66681857 0.66344783 0.61069523 0.64283251 0.7073377  0.71125639
#  0.62192895 0.64501401 0.67126127 0.63538842 0.70459825 0.71598789
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
grid_Pred=grid.predict(Independent)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'friedman_mse', 'max_features': None, 'splitter': 'random'}:

# %%
from sklearn.metrics import r2_score
r_score=r2_score(grid_Pred,Dependent)
print(r_score)
# Out:
# 0.9986653772918882

# %%
table=pd.DataFrame.from_dict(re)
print(table)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.006628      0.003637         0.001036        0.001312
# 1        0.003887      0.004217         0.003258        0.006516
# 2        0.004974      0.001860         0.001100        0.001963
# 3        0.001635      0.000969         0.000000        0.000000
# 4        0.005537      0.004529         0.001852        0.003436
# 5        0.003841      0.004705         0.000000        0.000000
# 6        0.027736      0.005233         0.003337        0.005981
# 7        0.027591      0.010856         0.000000        0.000000
# 8        0.031941      0.002224         0.001226        0.001170
# 9        0.028209      0.003611         0.000640        0.001281
# 10       0.058305      0.003564         0.001727        0.002402
# 11       0.044592      0.004307         0.001003        0.000902
# 12       0.006714      0.002441         0.000401        0.000587
# 13       0.001063      0.001321         0.000000        0.000000
# 14       0.005375      0.002479         0.000662        0.000673
# 15       0.001216      0.001187         0.000602        0.000755
# 16       0.005792      0.001145         0.002187        0.001326
# 17       0.003517      0.000636         0.001188        0.001183
# 18       0.001986      0.002847         0.000000        0.000000
# 19       0.001114      0.001774         0.000000        0.000000
# 20       0.001092      0.000917         0.000000        0.000000
# 21       0.000347      0.000694         0.000000        0.000000
# 22       0.001525      0.001930         0.000000        0.000000
# 23       0.000000      0.000000         0.000000        0.000000
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4    squared_error               None           best
# 5    squared_error               None         random
# 6   absolute_error               sqrt           best
# 7   absolute_error               sqrt         random
# 8   absolute_error               log2           best
# 9   absolute_error               log2         random
# 10  absolute_error               None           best
# 11  absolute_error               None         random
# 12    friedman_mse               sqrt           best
# 13    friedman_mse               sqrt         random
# 14    friedman_mse               log2           best
# 15    friedman_mse               log2         random
# 16    friedman_mse               None           best
# 17    friedman_mse               None         random
# 18         poisson               sqrt           best
# 19         poisson               sqrt         random
# 20         poisson               log2           best
# 21         poisson               log2         random
# 22         poisson               None           best
# 23         poisson               None         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.551241
# 1   {'criterion': 'squared_error', 'max_features':...           0.663788
# 2   {'criterion': 'squared_error', 'max_features':...           0.771567
# 3   {'criterion': 'squared_error', 'max_features':...           0.728744
# 4   {'criterion': 'squared_error', 'max_features':...           0.735885
# 5   {'criterion': 'squared_error', 'max_features':...           0.706705
# 6   {'criterion': 'absolute_error', 'max_features'...           0.672780
# 7   {'criterion': 'absolute_error', 'max_features'...           0.706429
# 8   {'criterion': 'absolute_error', 'max_features'...           0.759600
# 9   {'criterion': 'absolute_error', 'max_features'...           0.651506
# 10  {'criterion': 'absolute_error', 'max_features'...           0.712869
# 11  {'criterion': 'absolute_error', 'max_features'...           0.661539
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.564885
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.667096
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.620542
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.722398
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.714451
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.727634
# 18  {'criterion': 'poisson', 'max_features': 'sqrt...                NaN
# 19  {'criterion': 'poisson', 'max_features': 'sqrt...                NaN
# 20  {'criterion': 'poisson', 'max_features': 'log2...                NaN
# 21  {'criterion': 'poisson', 'max_features': 'log2...                NaN
# 22  {'criterion': 'poisson', 'max_features': None,...                NaN
# 23  {'criterion': 'poisson', 'max_features': None,...                NaN
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.655821           0.593884           0.684071
# 1            0.580720           0.694181           0.738946
# 2            0.626455           0.728172           0.751428
# 3            0.537384           0.645334           0.715173
# 4            0.645939           0.727680           0.695651
# 5            0.585141           0.675047           0.708664
# 6            0.585578           0.637651           0.715945
# 7            0.597512           0.666179           0.675812
# 8            0.413689           0.512161           0.650737
# 9            0.570392           0.633787           0.654148
# 10           0.606841           0.715853           0.741219
# 11           0.627847           0.755300           0.715545
# 12           0.446005           0.699658           0.737781
# 13           0.399317           0.726439           0.687781
# 14           0.666958           0.739148           0.589560
# 15           0.561674           0.676641           0.680235
# 16           0.661111           0.722759           0.704362
# 17           0.604001           0.785288           0.721976
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20                NaN                NaN                NaN
# 21                NaN                NaN                NaN
# 22                NaN                NaN                NaN
# 23                NaN                NaN                NaN
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.704653         0.637934        0.057194               15
# 1            0.531320         0.641791        0.075632               14
# 2            0.674551         0.710434        0.053052                3
# 3            0.597517         0.644831        0.071796               12
# 4            0.694724         0.699976        0.031696                6
# 5            0.732689         0.681649        0.051614                7
# 6            0.722139         0.666819        0.050912                9
# 7            0.671306         0.663448        0.035825               10
# 8            0.717289         0.610695        0.129351               18
# 9            0.704329         0.642833        0.043161               13
# 10           0.759906         0.707338        0.053130                4
# 11           0.796051         0.711256        0.060954                2
# 12           0.661316         0.621929        0.105088               17
# 13           0.744436         0.645014        0.125856               11
# 14           0.740099         0.671261        0.061014                8
# 15           0.535994         0.635388        0.072934               16
# 16           0.720308         0.704598        0.022649                5
# 17           0.741040         0.715988        0.060237                1
# 18                NaN              NaN             NaN               19
# 19                NaN              NaN             NaN               19
# 20                NaN              NaN             NaN               19
# 21                NaN              NaN             NaN               19
# 22                NaN              NaN             NaN               19
# 23                NaN              NaN             NaN               19

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[0.23251487]

# %%
import pickle
FileName="DecisionTree.sav"
pickle.dump(grid,open(FileName,"wb"))

# %%
loaded_model=pickle.load(open("DecisionTree.sav","rb"))
pre_int=sc.transform([[36,30,2,0,1]])
result=loaded_model.predict(pre_int)
print(result)
# Out:
# [2.53384758]
# c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
pre_output=scy.inverse_transform([result])
print(pre_output)
# Out:
# [[43943.8761]]
