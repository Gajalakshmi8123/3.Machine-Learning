# %%
import pandas as pd

# %%
Dataset=pd.read_csv('insurance_pre.csv')

# %%
Dataset.head()
# Out:
#    age     sex     bmi  children smoker      charges
# 0   19  female  27.900         0    yes  16884.92400
# 1   18    male  33.770         1     no   1725.55230
# 2   28    male  33.000         3     no   4449.46200
# 3   33    male  22.705         0     no  21984.47061
# 4   32    male  28.880         0     no   3866.85520

# %%
Dataset=pd.get_dummies(Dataset,dtype=int,drop_first=True)

# %%
Dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
Independent=Dataset[['age', 'bmi', 'children',  'sex_male', 'smoker_yes']]
Dependent=Dataset[['charges']]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
Independent=sc.fit_transform(Independent)

# %%
scy=StandardScaler()
Dependent=scy.fit_transform(Dependent)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
Param_grid={'criterion':['squared_error','absolute_error','friedman_mse','poisson'],
            'max_features': ['sqrt','log2',None],
            'splitter':['best','random']}

# %%
import pickle
FileName="scx.pkl"
pickle.dump(sc,open(FileName,"wb"))

# %%
import pickle
FileName="scy.pkl"
pickle.dump(scy,open(FileName,'wb'))

# %%
grid = GridSearchCV(DecisionTreeRegressor(), Param_grid, refit = True, verbose= 3,n_jobs=-1)
grid.fit(Independent,Dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 30 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_classes.py", line 1377, in fit
#     super()._fit(
#   File "c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_classes.py", line 269, in _fit
#     raise ValueError(
# ValueError: Some value(s) of y are negative which is not allowed for Poisson regression.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.66384937 0.62731154 0.65290734 0.66303623 0.70974488 0.70918976
#  0.67658283 0.63400737 0.65046987 0.63490013 0.70848061 0.68671492
#  0.68947538 0.64823812 0.64558376 0.64469517 0.69932356 0.68579808
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
grid_Pred=grid.predict(Independent)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'squared_error', 'max_features': None, 'splitter': 'best'}:

# %%
from sklearn.metrics import r2_score
r_score=r2_score(grid_Pred,Dependent)
print(r_score)
# Out:
# 0.9986653772918882

# %%
table=pd.DataFrame.from_dict(re)
print(table)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.007023      0.003543         0.000886        0.001490
# 1        0.004390      0.003760         0.003077        0.003385
# 2        0.000463      0.000704         0.000000        0.000000
# 3        0.003931      0.004180         0.000205        0.000410
# 4        0.003857      0.003244         0.002306        0.002231
# 5        0.002809      0.002055         0.001061        0.001710
# 6        0.030217      0.004229         0.003771        0.004363
# 7        0.022546      0.003968         0.000000        0.000000
# 8        0.035321      0.006541         0.000000        0.000000
# 9        0.028078      0.003196         0.000000        0.000000
# 10       0.064523      0.002975         0.002387        0.001360
# 11       0.051956      0.003780         0.000788        0.001146
# 12       0.003507      0.000379         0.000415        0.000831
# 13       0.003632      0.000697         0.000321        0.000642
# 14       0.005138      0.002801         0.001634        0.002783
# 15       0.003461      0.002267         0.001745        0.002726
# 16       0.009461      0.001924         0.000369        0.000739
# 17       0.003503      0.000752         0.001705        0.000955
# 18       0.000911      0.000957         0.000000        0.000000
# 19       0.000709      0.000884         0.000000        0.000000
# 20       0.000746      0.000774         0.000000        0.000000
# 21       0.000871      0.000813         0.000000        0.000000
# 22       0.000000      0.000000         0.000000        0.000000
# 23       0.002270      0.002782         0.000000        0.000000
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4    squared_error               None           best
# 5    squared_error               None         random
# 6   absolute_error               sqrt           best
# 7   absolute_error               sqrt         random
# 8   absolute_error               log2           best
# 9   absolute_error               log2         random
# 10  absolute_error               None           best
# 11  absolute_error               None         random
# 12    friedman_mse               sqrt           best
# 13    friedman_mse               sqrt         random
# 14    friedman_mse               log2           best
# 15    friedman_mse               log2         random
# 16    friedman_mse               None           best
# 17    friedman_mse               None         random
# 18         poisson               sqrt           best
# 19         poisson               sqrt         random
# 20         poisson               log2           best
# 21         poisson               log2         random
# 22         poisson               None           best
# 23         poisson               None         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.637952
# 1   {'criterion': 'squared_error', 'max_features':...           0.716424
# 2   {'criterion': 'squared_error', 'max_features':...           0.652229
# 3   {'criterion': 'squared_error', 'max_features':...           0.695450
# 4   {'criterion': 'squared_error', 'max_features':...           0.739683
# 5   {'criterion': 'squared_error', 'max_features':...           0.696298
# 6   {'criterion': 'absolute_error', 'max_features'...           0.641126
# 7   {'criterion': 'absolute_error', 'max_features'...           0.689684
# 8   {'criterion': 'absolute_error', 'max_features'...           0.552468
# 9   {'criterion': 'absolute_error', 'max_features'...           0.659531
# 10  {'criterion': 'absolute_error', 'max_features'...           0.751387
# 11  {'criterion': 'absolute_error', 'max_features'...           0.667064
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.703391
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.661226
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.794397
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.717790
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.726148
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.680207
# 18  {'criterion': 'poisson', 'max_features': 'sqrt...                NaN
# 19  {'criterion': 'poisson', 'max_features': 'sqrt...                NaN
# 20  {'criterion': 'poisson', 'max_features': 'log2...                NaN
# 21  {'criterion': 'poisson', 'max_features': 'log2...                NaN
# 22  {'criterion': 'poisson', 'max_features': None,...                NaN
# 23  {'criterion': 'poisson', 'max_features': None,...                NaN
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.643839           0.646804           0.730356
# 1            0.486790           0.620115           0.672323
# 2            0.631946           0.744103           0.502966
# 3            0.550845           0.720472           0.726055
# 4            0.660197           0.707173           0.735886
# 5            0.656228           0.713464           0.709348
# 6            0.612403           0.729984           0.693517
# 7            0.487885           0.622480           0.657021
# 8            0.636348           0.668386           0.709023
# 9            0.559208           0.712578           0.643605
# 10           0.584906           0.725638           0.743020
# 11           0.536116           0.730962           0.724439
# 12           0.605538           0.725909           0.679247
# 13           0.534486           0.715305           0.706687
# 14           0.617513           0.467820           0.631546
# 15           0.544044           0.612198           0.698639
# 16           0.653415           0.725364           0.707110
# 17           0.600634           0.729431           0.687564
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20                NaN                NaN                NaN
# 21                NaN                NaN                NaN
# 22                NaN                NaN                NaN
# 23                NaN                NaN                NaN
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.660296         0.663849        0.034051                9
# 1            0.640906         0.627312        0.077395               18
# 2            0.733292         0.652907        0.086834               11
# 3            0.622360         0.663036        0.067175               10
# 4            0.705786         0.709745        0.028485                1
# 5            0.770611         0.709190        0.036775                2
# 6            0.705884         0.676583        0.043297                8
# 7            0.712967         0.634007        0.079182               17
# 8            0.686124         0.650470        0.054451               12
# 9            0.599580         0.634900        0.052332               16
# 10           0.737451         0.708481        0.062351                3
# 11           0.774993         0.686715        0.082753                6
# 12           0.733291         0.689475        0.046024                5
# 13           0.623487         0.648238        0.065780               13
# 14           0.716642         0.645584        0.109343               14
# 15           0.650805         0.644695        0.062413               15
# 16           0.684582         0.699324        0.027507                4
# 17           0.731155         0.685798        0.047431                7
# 18                NaN              NaN             NaN               19
# 19                NaN              NaN             NaN               19
# 20                NaN              NaN             NaN               19
# 21                NaN              NaN             NaN               19
# 22                NaN              NaN             NaN               19
# 23                NaN              NaN             NaN               19

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[1.92556184]

# %%
import pickle
FileName="DecisionTree.sav"
pickle.dump(grid,open(FileName,"wb"))

# %%
loaded_model=pickle.load(open("DecisionTree.sav","rb"))
pre_int=sc.transform([[36,30,2,0,1]])
result=loaded_model.predict(pre_int)
print(result)
# Out:
# [0.63720465]
# c:\Users\Gajalakshmi G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
pre_output=scy.inverse_transform([result])
print(pre_output)
# Out:
# [[20984.0936]]
